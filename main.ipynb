# %%
import requests
from bs4 import BeautifulSoup
url="https://www.pararius.com/apartments/amsterdam?ac=1"
page=requests.get(url)

# %%
soup = BeautifulSoup(page.content,'html.parser')
lists=soup.find_all('section', class_='listing-search-item')
overall=[]
for list in lists:
  title=list.find('a',class_="listing-search-item__link--title").text.replace('\n','')
  location=list.find('div',class_="listing-search-item__location").text.replace('\n','')
  Area=list.find('li',class_="illustrated-features__item--surface-area").text.replace('\n','')
  price=list.find('div',class_="listing-search-item__price").text.replace('\n','')
  res_names=[title,location,Area,price]
  overall.append(res_names)

# %%
import pandas as pd

# %%
Hotels_data=pd.DataFrame(overall,columns=['Hotel_Name','Hotel_Address','Overall_Area','Price'])
Hotels_data
# Out:
#                               Hotel_Name  \
# 0           House Admiraal De Ruijterweg
# 1                    House Keizersgracht
# 2                      Studio Heiligeweg
# 3                Apartment Alexanderkade
# 4              Apartment Overtoom 435 II
# 5       Apartment Wilhelminastraat 129 D
# 6      Apartment Bos en Lommerweg 321 II
# 7           Apartment Warmoesstraat 50 G
# 8          Apartment Jan de Jonghkade 29
# 9            Apartment Rozengracht 239 I
# 10           Apartment Hobbemakade 82 II
# 11  Apartment Roemer Visscherstraat 11 F
# 12          Apartment Warmoesstraat 48 C
# 13              Apartment Spuistraat 3 N
# 14            Apartment Beursstraat 33 H
# 15                  Apartment Javastraat
# 16             Apartment Februariplein 4
# 17               Apartment Van Woustraat
# 18                  Apartment Loevestein
# 19   Apartment Kleine Wittenburgerstraat
# 20      Apartment Moreelsestraat 37 huis
# 21               House Zocherstraat 23 P
# 22     Apartment Pieter Lastmankade 30 C
# 23                    Apartment Hoofdweg
# 24         Apartment Sarphatistraat 44 E
# 25          Apartment Vossiusstraat 49 1
# 26               Apartment Sausalitolaan
# 27               Apartment Céramiquelaan
# 28             Apartment Havikshorst 121
# 29              Apartment Brouwersgracht
# 30              Apartment Panamalaan 242
# 31                    Studio Nieuwevaart
#
#                                         Hotel_Address Overall_Area  \
# 0                1055 MT Amsterdam (Landlust)               137 m²
# 1               1015 CP Amsterdam (Grachtengordel-...        65 m²
# 2               1012 XP Amsterdam (Burgwallen-Nieu...        40 m²
# 3               1018 CH Amsterdam (Weesperbuurt/Pl...        80 m²
# 4               1054 KE Amsterdam (Overtoomse Slui...        63 m²
# 5               1054 WB Amsterdam (Overtoomse Slui...        60 m²
# 6               1055 DZ Amsterdam (Erasmuspark)   ...        72 m²
# 7               1012 JE Amsterdam (Burgwallen-Oude...        79 m²
# 8               1063 MH Amsterdam (Slotermeer-Noor...        96 m²
# 9                 1016 SX Amsterdam (Jordaan)                45 m²
# 10              1071 XP Amsterdam (Museumkwartier)...        66 m²
# 11              1054 EV Amsterdam (Vondelbuurt)   ...        40 m²
# 12              1012 JE Amsterdam (Burgwallen-Oude...       101 m²
# 13              1012 SP Amsterdam (Burgwallen-Nieu...        45 m²
# 14              1012 JV Amsterdam (Burgwallen-Oude...        40 m²
# 15              1095 CL Amsterdam (Indische Buurt ...        85 m²
# 16              1011 MT Amsterdam (Nieuwmarkt/Last...        95 m²
# 17              1074 AB Amsterdam (Oude Pijp)                53 m²
# 18              1082 XG Amsterdam (Buitenveldert-W...        65 m²
# 19              1018 LZ Amsterdam (Oostelijke Eila...        55 m²
# 20              1071 BJ Amsterdam (Museumkwartier)...       240 m²
# 21              1054 LR Amsterdam (Overtoomse Slui...       146 m²
# 22              1075 KK Amsterdam (Willemspark)   ...       207 m²
# 23              1058 AW Amsterdam (Westindische Bu...       126 m²
# 24              1018 GN Amsterdam (Weesperbuurt/Pl...        70 m²
# 25              1071 AK Amsterdam (Museumkwartier)...        89 m²
# 26              1031 KE Amsterdam (Noordelijke IJ-...        67 m²
# 27              1031 KG Amsterdam (Noordelijke IJ-...        70 m²
# 28              1083 TP Amsterdam (Buitenveldert-O...        76 m²
# 29              1013 GW Amsterdam (Haarlemmerbuurt...        60 m²
# 30              1019 AZ Amsterdam (Oostelijk Haven...       105 m²
# 31              1018 AA Amsterdam (Oostelijke Eila...        27 m²
#
#                                            Price
# 0                   €2,500 per month
# 1                   €2,150 per month
# 2                   €1,550 per month
# 3                   €1,650 per month
# 4                   €1,750 per month
# 5                   €2,650 per month
# 6                   €1,750 per month
# 7                   €2,350 per month
# 8                   €1,850 per month
# 9                   €1,500 per month
# 10                  €1,950 per month
# 11                  €1,650 per month
# 12                  €3,000 per month
# 13                  €2,100 per month
# 14                  €1,675 per month
# 15                  €2,350 per month
# 16                  €2,750 per month
# 17                  €1,795 per month
# 18                  €1,700 per month
# 19                  €1,750 per month
# 20                  €6,500 per month
# 21                  €5,250 per month
# 22                  €7,500 per month
# 23                  €3,200 per month
# 24                  €1,700 per month
# 25                  €2,550 per month
# 26                  €1,875 per month
# 27                  €1,950 per month
# 28                  €1,750 per month
# 29                  €2,100 per month
# 30                  €2,250 per month
# 31                  €1,325 per month

# %%
Hotels_data.to_excel("Hotels_data.xlsx")
